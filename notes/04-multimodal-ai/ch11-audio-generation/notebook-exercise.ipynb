# %% [markdown]
# # CPU Text-to-Speech Quick Win
#
# This notebook shows a minimal text-to-speech demo using a pretrained model that runs on a stock CPU (no GPU required).
#
# Model used: `facebook/mms-tts-eng` (Hugging Face Transformers).

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Process data
#
# Hint:
#    # implement using the APIs described above

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Process data
# 2. Compute `MODEL_ID` using `from_pretrained()`
# 3. Process data
#
# Hint:
#    tokenizer = AutoTokenizer.from_pretrained(???)
#    model = VitsModel.from_pretrained(???)

# %%
def speak(text: str, out_file: str = "quickwin_tts.wav"):
    """
    TODO #3: Implement `speak()`.

    Steps:
    1. Define helper function `speak()`
    2. Call `write_wav()` to produce the result
    3. Process data

    Hint:
    # implement using the APIs described above

    Returns: result
    """
    raise NotImplementedError("TODO: implement speak()")

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Call `speak()` to produce the result
#
# Hint:
#    # implement using the APIs described above
