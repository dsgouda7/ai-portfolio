# %% [markdown]
# # Ch.6 — Model Serving Frameworks
#
# > **Learning goal:** Deploy Llama-2-7B with vLLM, ONNX Runtime, and compare throughput/latency/memory against HuggingFace baseline.
# >
# > **Prerequisites:** Ch.5 (Inference Optimization), basic Docker knowledge
# >
# > **Estimated time:** 45 minutes (excluding model downloads)
#
# ## What You'll Build
#
#
# - Baseline HuggingFace Transformers inference (10 req/s)
# - vLLM deployment with continuous batching (150 req/s)
# - ONNX Runtime quantized inference (24 req/s, 50% less memory)
# - Performance comparison table and visualization
# - Production API server with FastAPI + Prometheus metrics
#
# **Note:** This notebook runs locally on a single GPU. For multi-GPU and Azure deployment, see `notebook_supplement.ipynb`.

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Call `is_available()` to produce the result
# 2. Process data
# 3. Plot results -- call `use()`
# 4. Process data
#
# Hint:
#    # implement using the APIs described above

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Process data
# 2. Call `7B()` to produce the result
# 3. Compute `model_name` using `from_pretrained()`
# 4. Call `memory_allocated()` to produce the result
# 5. Compute `prompt` using `tokenizer()`
# 6. Call `Warmup()` to produce the result
# 7. Compute `start` using `time()`
# 8. Compute `response` using `decode()`
# 9. Compute `baseline_results` using `memory_allocated()`
#
# Hint:
#    tokenizer = AutoTokenizer.from_pretrained(???)
#    model = AutoModelForCausalLM.from_pretrained(???)
#    _ = model.generate(???)
#    start = time.time(???)

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Call `throughput()` to produce the result
# 2. Compute `num_requests` using `time()`
# 3. Call `if()` to produce the result
# 4. Call `no_grad()` to produce the result
# 5. Compute `duration` using `time()`
# 6. Process data
# 7. Compute `baseline_results["throughput_rps"]`
# 8. Call `empty_cache()` to produce the result
#
# Hint:
#    start = time.time(???)
#    elapsed = time.time(???)
#    _ = model.generate(???)
#    duration = time.time(???)

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Process data
# 2. Compute `llm` using `LLM()`
# 3. Process data
# 4. Compute `sampling_params` using `SamplingParams()`
# 5. Compute `_` using `generate()`
# 6. Compute `prompt` using `latency()`
# 7. Compute `start` using `time()`
# 8. Compute `response` using `ms()`
# 9. Compute `vllm_results` using `memory_allocated()`
#
# Hint:
#    llm = LLM(model=???, tensor_parallel_size=???)
#    sampling_params = SamplingParams(temperature=???)
#    _ = llm.generate(???)
#    start = time.time(???)

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Call `throughput()` to produce the result
# 2. Compute `prompts`
# 3. Compute `start` using `time()`
# 4. Compute `vllm_throughput`
# 5. Process data
# 6. Compute `memory_used` using `memory_allocated()`
# 7. Compute `vllm_results["throughput_rps"]`
# 8. Process data
#
# Hint:
#    start = time.time(???)
#    outputs = llm.generate(???)
#    duration = time.time(???)
#    memory_used = torch.cuda.memory_allocated(???)

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Process data
# 2. Compute `onnx_dir` using `ONNX()`
# 3. Call `exists()` to produce the result
# 4. Process data
# 5. Compute `onnx_files` using `glob()`
#
# Hint:
#    onnx_files = glob.glob(???)

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Process data
# 2. Compute `ort_model` using `from_pretrained()`
# 3. Process data
# 4. Compute `inputs` using `ort_tokenizer()`
# 5. Compute `prompt` using `latency()`
# 6. Compute `start` using `time()`
# 7. Compute `response` using `decode()`
# 8. Compute `start` using `throughput()`
# 9. Compute `onnx_throughput`
# 10. Call `memory_allocated()` to produce the result
# 11. Compute `onnx_results` using `memory_allocated()`
# 12. Process data
#
# Hint:
#    ort_model = ORTModelForCausalLM.from_pretrained(???)
#    ort_tokenizer = AutoTokenizer.from_pretrained(???)
#    _ = ort_model.generate(???)
#    start = time.time(???)

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Process data
# 2. Compute `results_df` using `DataFrame()`
# 3. Call `to_string()` to produce the result
# 4. Call `iterrows()` to produce the result
# 5. Process data
# 6. Plot results -- call `subplots()`
# 7. Compute `frameworks` using `tolist()`
# 8. Call `bar()` to produce the result
# 9. Call `text()` to produce the result
# 10. Compute `memories` using `tolist()`
# 11. Call `text()` to produce the result
# 12. Plot results -- call `tight_layout()`
# 13. Process data
#
# Hint:
#    results_df = pd.DataFrame(???)

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Process data
# 2. Call `empty_cache()` to produce the result
# 3. Compute `llm` using `LLM()`
# 4. Compute `sampling_params` using `SamplingParams()`
# 5. Compute `batch_sizes`
# 6. Call `reset_peak_memory_stats()` to produce the result
# 7. Call `generate()` to produce the result
# 8. Call `max_memory_allocated()` to produce the result
# 9. Process data
# 10. Plot results -- call `subplots()`
# 11. Plot results -- call `plot()`
# 12. Compute `base_memory` using `growth()`
# 13. Plot results -- call `plot()`
# 14. Plot results -- call `axhline()`
# 15. Plot results -- call `set_xlabel()`
# 16. Plot results -- call `tight_layout()`
# 17. Process data
#
# Hint:
#    llm = LLM(model=???, tensor_parallel_size=???)
#    sampling_params = SamplingParams(temperature=???, max_tokens=???)
#    _ = llm.generate(???)
#    peak_memory = torch.cuda.max_memory_allocated(???)

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Process data
# 2. Compute `decision_tree`
# 3. Call `LLM()` to produce the result
# 4. Call `LLMs()` to produce the result
# 5. Process data
# 6. Plot results -- call `subplots()`
# 7. Compute `decision_text` using `throughput()`
# 8. Plot results -- call `text()`
# 9. Plot results -- call `tight_layout()`
# 10. Process data
#
# Hint:
#    ax = plt.subplots(???)
