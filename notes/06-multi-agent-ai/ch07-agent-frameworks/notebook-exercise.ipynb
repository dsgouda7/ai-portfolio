# %%
# TODO: Implement this cell
#
# Steps:
# 1. Define two negotiation node variants producing different final prices:
#    a. negotiation_node_A(state): aggressive 15% discount on state["total"],
#       set state["strategy"]="A", state["status"]="fulfilled"
#    b. negotiation_node_B(state): relationship 9% discount,
#       set state["strategy"]="B", state["status"]="fulfilled"
# 2. Build two LangGraph graphs (validate -> inventory -> negotiate_A/B):
#    Use the validate_order and check_inventory nodes defined earlier.
#    Compile both as app_a and app_b (no checkpointer needed for this demo)
# 3. Simulate 10 orders: for each, pick app_a or app_b with 50/50 probability
#    Run chosen graph with a test POState (total=800.0); collect results
# 4. Print a per-run table: run #, strategy, final_price, status
# 5. Compute and print summary: Strategy A vs B - count, avg final_price, winner
#
# Hint:
#   import random
#   def negotiation_node_A(state):
#       return {**state, "total": round(state["total"] * ???, 2),
#               "strategy": "A", "status": "fulfilled"}
#   def negotiation_node_B(state):
#       return {**state, "total": round(state["total"] * ???, 2),
#               "strategy": "B", "status": "fulfilled"}
#
#   from langgraph.graph import StateGraph, END
#   graph_a = StateGraph(POState)
#   graph_a.add_node("validate",  validate_order)
#   graph_a.add_node("inventory", check_inventory)
#   graph_a.add_node("negotiate", negotiation_node_A)
#   graph_a.set_entry_point("validate")
#   graph_a.add_edge("validate", "inventory")
#   graph_a.add_edge("inventory", "negotiate")
#   graph_a.add_edge("negotiate", END)
#   app_a = graph_a.compile()  # similarly build app_b with negotiation_node_B
#
#   results = []
#   for i in range(10):
#       app = app_a if random.random() < 0.5 else app_b
#       state = app.invoke({"order_id": f"ORD-{i}", "items": [], "total": 800.0,
#                           "status": "", "approval": "", "notes": ""})
#       results.append(state)
#
#   for s in ["A", "B"]:
#       subset = [r for r in results if r["strategy"] == s]
#       avg = sum(r["total"] for r in subset) / max(len(subset), 1)
#       print(f"Strategy {s}: {len(subset)} runs, avg final_price={avg:.2f}")

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Define two negotiation node variants producing different final prices:
#    a. negotiation_node_A(state): aggressive 15% discount on state["total"],
#       set state["strategy"]="A", state["status"]="fulfilled"
#    b. negotiation_node_B(state): relationship 9% discount,
#       set state["strategy"]="B", state["status"]="fulfilled"
# 2. Build two LangGraph graphs (validate -> inventory -> negotiate_A/B):
#    Use the validate_order and check_inventory nodes defined earlier.
#    Compile both as app_a and app_b (no checkpointer needed for this demo)
# 3. Simulate 10 orders: for each, pick app_a or app_b with 50/50 probability
#    Run chosen graph with a test POState (total=800.0); collect results
# 4. Print a per-run table: run #, strategy, final_price, status
# 5. Compute and print summary: Strategy A vs B - count, avg final_price, winner
#
# Hint:
#   import random
#   def negotiation_node_A(state):
#       return {**state, "total": round(state["total"] * ???, 2),
#               "strategy": "A", "status": "fulfilled"}
#   def negotiation_node_B(state):
#       return {**state, "total": round(state["total"] * ???, 2),
#               "strategy": "B", "status": "fulfilled"}
#
#   from langgraph.graph import StateGraph, END
#   graph_a = StateGraph(POState)
#   graph_a.add_node("validate",  validate_order)
#   graph_a.add_node("inventory", check_inventory)
#   graph_a.add_node("negotiate", negotiation_node_A)
#   graph_a.set_entry_point("validate")
#   graph_a.add_edge("validate", "inventory")
#   graph_a.add_edge("inventory", "negotiate")
#   graph_a.add_edge("negotiate", END)
#   app_a = graph_a.compile()  # similarly build app_b with negotiation_node_B
#
#   results = []
#   for i in range(10):
#       app = app_a if random.random() < 0.5 else app_b
#       state = app.invoke({"order_id": f"ORD-{i}", "items": [], "total": 800.0,
#                           "status": "", "approval": "", "notes": ""})
#       results.append(state)
#
#   for s in ["A", "B"]:
#       subset = [r for r in results if r["strategy"] == s]
#       avg = sum(r["total"] for r in subset) / max(len(subset), 1)
#       print(f"Strategy {s}: {len(subset)} runs, avg final_price={avg:.2f}")

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Define two negotiation node variants producing different final prices:
#    a. negotiation_node_A(state): aggressive 15% discount on state["total"],
#       set state["strategy"]="A", state["status"]="fulfilled"
#    b. negotiation_node_B(state): relationship 9% discount,
#       set state["strategy"]="B", state["status"]="fulfilled"
# 2. Build two LangGraph graphs (validate -> inventory -> negotiate_A/B):
#    Use the validate_order and check_inventory nodes defined earlier.
#    Compile both as app_a and app_b (no checkpointer needed for this demo)
# 3. Simulate 10 orders: for each, pick app_a or app_b with 50/50 probability
#    Run chosen graph with a test POState (total=800.0); collect results
# 4. Print a per-run table: run #, strategy, final_price, status
# 5. Compute and print summary: Strategy A vs B - count, avg final_price, winner
#
# Hint:
#   import random
#   def negotiation_node_A(state):
#       return {**state, "total": round(state["total"] * ???, 2),
#               "strategy": "A", "status": "fulfilled"}
#   def negotiation_node_B(state):
#       return {**state, "total": round(state["total"] * ???, 2),
#               "strategy": "B", "status": "fulfilled"}
#
#   from langgraph.graph import StateGraph, END
#   graph_a = StateGraph(POState)
#   graph_a.add_node("validate",  validate_order)
#   graph_a.add_node("inventory", check_inventory)
#   graph_a.add_node("negotiate", negotiation_node_A)
#   graph_a.set_entry_point("validate")
#   graph_a.add_edge("validate", "inventory")
#   graph_a.add_edge("inventory", "negotiate")
#   graph_a.add_edge("negotiate", END)
#   app_a = graph_a.compile()  # similarly build app_b with negotiation_node_B
#
#   results = []
#   for i in range(10):
#       app = app_a if random.random() < 0.5 else app_b
#       state = app.invoke({"order_id": f"ORD-{i}", "items": [], "total": 800.0,
#                           "status": "", "approval": "", "notes": ""})
#       results.append(state)
#
#   for s in ["A", "B"]:
#       subset = [r for r in results if r["strategy"] == s]
#       avg = sum(r["total"] for r in subset) / max(len(subset), 1)
#       print(f"Strategy {s}: {len(subset)} runs, avg final_price={avg:.2f}")

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Define two negotiation node variants producing different final prices:
#    a. negotiation_node_A(state): aggressive 15% discount on state["total"],
#       set state["strategy"]="A", state["status"]="fulfilled"
#    b. negotiation_node_B(state): relationship 9% discount,
#       set state["strategy"]="B", state["status"]="fulfilled"
# 2. Build two LangGraph graphs (validate -> inventory -> negotiate_A/B):
#    Use the validate_order and check_inventory nodes defined earlier.
#    Compile both as app_a and app_b (no checkpointer needed for this demo)
# 3. Simulate 10 orders: for each, pick app_a or app_b with 50/50 probability
#    Run chosen graph with a test POState (total=800.0); collect results
# 4. Print a per-run table: run #, strategy, final_price, status
# 5. Compute and print summary: Strategy A vs B - count, avg final_price, winner
#
# Hint:
#   import random
#   def negotiation_node_A(state):
#       return {**state, "total": round(state["total"] * ???, 2),
#               "strategy": "A", "status": "fulfilled"}
#   def negotiation_node_B(state):
#       return {**state, "total": round(state["total"] * ???, 2),
#               "strategy": "B", "status": "fulfilled"}
#
#   from langgraph.graph import StateGraph, END
#   graph_a = StateGraph(POState)
#   graph_a.add_node("validate",  validate_order)
#   graph_a.add_node("inventory", check_inventory)
#   graph_a.add_node("negotiate", negotiation_node_A)
#   graph_a.set_entry_point("validate")
#   graph_a.add_edge("validate", "inventory")
#   graph_a.add_edge("inventory", "negotiate")
#   graph_a.add_edge("negotiate", END)
#   app_a = graph_a.compile()  # similarly build app_b with negotiation_node_B
#
#   results = []
#   for i in range(10):
#       app = app_a if random.random() < 0.5 else app_b
#       state = app.invoke({"order_id": f"ORD-{i}", "items": [], "total": 800.0,
#                           "status": "", "approval": "", "notes": ""})
#       results.append(state)
#
#   for s in ["A", "B"]:
#       subset = [r for r in results if r["strategy"] == s]
#       avg = sum(r["total"] for r in subset) / max(len(subset), 1)
#       print(f"Strategy {s}: {len(subset)} runs, avg final_price={avg:.2f}")

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Define two negotiation node variants producing different final prices:
#    a. negotiation_node_A(state): aggressive 15% discount on state["total"],
#       set state["strategy"]="A", state["status"]="fulfilled"
#    b. negotiation_node_B(state): relationship 9% discount,
#       set state["strategy"]="B", state["status"]="fulfilled"
# 2. Build two LangGraph graphs (validate -> inventory -> negotiate_A/B):
#    Use the validate_order and check_inventory nodes defined earlier.
#    Compile both as app_a and app_b (no checkpointer needed for this demo)
# 3. Simulate 10 orders: for each, pick app_a or app_b with 50/50 probability
#    Run chosen graph with a test POState (total=800.0); collect results
# 4. Print a per-run table: run #, strategy, final_price, status
# 5. Compute and print summary: Strategy A vs B - count, avg final_price, winner
#
# Hint:
#   import random
#   def negotiation_node_A(state):
#       return {**state, "total": round(state["total"] * ???, 2),
#               "strategy": "A", "status": "fulfilled"}
#   def negotiation_node_B(state):
#       return {**state, "total": round(state["total"] * ???, 2),
#               "strategy": "B", "status": "fulfilled"}
#
#   from langgraph.graph import StateGraph, END
#   graph_a = StateGraph(POState)
#   graph_a.add_node("validate",  validate_order)
#   graph_a.add_node("inventory", check_inventory)
#   graph_a.add_node("negotiate", negotiation_node_A)
#   graph_a.set_entry_point("validate")
#   graph_a.add_edge("validate", "inventory")
#   graph_a.add_edge("inventory", "negotiate")
#   graph_a.add_edge("negotiate", END)
#   app_a = graph_a.compile()  # similarly build app_b with negotiation_node_B
#
#   results = []
#   for i in range(10):
#       app = app_a if random.random() < 0.5 else app_b
#       state = app.invoke({"order_id": f"ORD-{i}", "items": [], "total": 800.0,
#                           "status": "", "approval": "", "notes": ""})
#       results.append(state)
#
#   for s in ["A", "B"]:
#       subset = [r for r in results if r["strategy"] == s]
#       avg = sum(r["total"] for r in subset) / max(len(subset), 1)
#       print(f"Strategy {s}: {len(subset)} runs, avg final_price={avg:.2f}")

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Define two negotiation node variants producing different final prices:
#    a. negotiation_node_A(state): aggressive 15% discount on state["total"],
#       set state["strategy"]="A", state["status"]="fulfilled"
#    b. negotiation_node_B(state): relationship 9% discount,
#       set state["strategy"]="B", state["status"]="fulfilled"
# 2. Build two LangGraph graphs (validate -> inventory -> negotiate_A/B):
#    Use the validate_order and check_inventory nodes defined earlier.
#    Compile both as app_a and app_b (no checkpointer needed for this demo)
# 3. Simulate 10 orders: for each, pick app_a or app_b with 50/50 probability
#    Run chosen graph with a test POState (total=800.0); collect results
# 4. Print a per-run table: run #, strategy, final_price, status
# 5. Compute and print summary: Strategy A vs B - count, avg final_price, winner
#
# Hint:
#   import random
#   def negotiation_node_A(state):
#       return {**state, "total": round(state["total"] * ???, 2),
#               "strategy": "A", "status": "fulfilled"}
#   def negotiation_node_B(state):
#       return {**state, "total": round(state["total"] * ???, 2),
#               "strategy": "B", "status": "fulfilled"}
#
#   from langgraph.graph import StateGraph, END
#   graph_a = StateGraph(POState)
#   graph_a.add_node("validate",  validate_order)
#   graph_a.add_node("inventory", check_inventory)
#   graph_a.add_node("negotiate", negotiation_node_A)
#   graph_a.set_entry_point("validate")
#   graph_a.add_edge("validate", "inventory")
#   graph_a.add_edge("inventory", "negotiate")
#   graph_a.add_edge("negotiate", END)
#   app_a = graph_a.compile()  # similarly build app_b with negotiation_node_B
#
#   results = []
#   for i in range(10):
#       app = app_a if random.random() < 0.5 else app_b
#       state = app.invoke({"order_id": f"ORD-{i}", "items": [], "total": 800.0,
#                           "status": "", "approval": "", "notes": ""})
#       results.append(state)
#
#   for s in ["A", "B"]:
#       subset = [r for r in results if r["strategy"] == s]
#       avg = sum(r["total"] for r in subset) / max(len(subset), 1)
#       print(f"Strategy {s}: {len(subset)} runs, avg final_price={avg:.2f}")

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Define two negotiation node variants producing different final prices:
#    a. negotiation_node_A(state): aggressive 15% discount on state["total"],
#       set state["strategy"]="A", state["status"]="fulfilled"
#    b. negotiation_node_B(state): relationship 9% discount,
#       set state["strategy"]="B", state["status"]="fulfilled"
# 2. Build two LangGraph graphs (validate -> inventory -> negotiate_A/B):
#    Use the validate_order and check_inventory nodes defined earlier.
#    Compile both as app_a and app_b (no checkpointer needed for this demo)
# 3. Simulate 10 orders: for each, pick app_a or app_b with 50/50 probability
#    Run chosen graph with a test POState (total=800.0); collect results
# 4. Print a per-run table: run #, strategy, final_price, status
# 5. Compute and print summary: Strategy A vs B - count, avg final_price, winner
#
# Hint:
#   import random
#   def negotiation_node_A(state):
#       return {**state, "total": round(state["total"] * ???, 2),
#               "strategy": "A", "status": "fulfilled"}
#   def negotiation_node_B(state):
#       return {**state, "total": round(state["total"] * ???, 2),
#               "strategy": "B", "status": "fulfilled"}
#
#   from langgraph.graph import StateGraph, END
#   graph_a = StateGraph(POState)
#   graph_a.add_node("validate",  validate_order)
#   graph_a.add_node("inventory", check_inventory)
#   graph_a.add_node("negotiate", negotiation_node_A)
#   graph_a.set_entry_point("validate")
#   graph_a.add_edge("validate", "inventory")
#   graph_a.add_edge("inventory", "negotiate")
#   graph_a.add_edge("negotiate", END)
#   app_a = graph_a.compile()  # similarly build app_b with negotiation_node_B
#
#   results = []
#   for i in range(10):
#       app = app_a if random.random() < 0.5 else app_b
#       state = app.invoke({"order_id": f"ORD-{i}", "items": [], "total": 800.0,
#                           "status": "", "approval": "", "notes": ""})
#       results.append(state)
#
#   for s in ["A", "B"]:
#       subset = [r for r in results if r["strategy"] == s]
#       avg = sum(r["total"] for r in subset) / max(len(subset), 1)
#       print(f"Strategy {s}: {len(subset)} runs, avg final_price={avg:.2f}")
