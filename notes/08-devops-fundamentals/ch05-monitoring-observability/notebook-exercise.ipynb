# %% [markdown]
# # Ch.5 — Monitoring & Observability (Local Stack)
#
# > **Goal:** Instrument a Flask app with Prometheus metrics, deploy the full monitoring stack locally with Docker Compose, and build Grafana dashboards to visualize request rate, latency, and error rate.
# >
# > **Tech stack:** Python 3.11, Flask, prometheus_client, Docker Compose, Prometheus, Grafana, Alertmanager
# >
# > **What you'll build:** A production-grade observability stack running entirely on your local machine — no cloud dependencies.

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Install required packages: `prometheus-client flask requests`
#
# Hint:
#   !pip install prometheus-client flask requests

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Tally values using `collections.Counter`
# 2. Wait for services to become ready using `time.sleep(random.uniform(0.05, 0.3)`
# 3. Wait for services to become ready using `time.sleep(random.uniform(0.2, 0.8)`
# 4. Open file `'app.py'` for writing and write the content
#
# Hint:
#   counts = Counter(???)
#   time.sleep(random.uniform(0.05, 0.3)
#   time.sleep(random.uniform(0.2, 0.8)

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Open file `'prometheus.yml'` for writing and write the content
# 2. Open file `'docker-compose.yml'` for writing and write the content
# 3. Open file `'Dockerfile'` for writing and write the content
#
# Hint:
#   with open('prometheus.yml', 'w') as f:
#     f.write(content)
#   with open('docker-compose.yml', 'w') as f:
#     f.write(content)
#   with open('Dockerfile', 'w') as f:
#     f.write(content)

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Wait for services to become ready using `time.sleep(10)`
# 2. Make an HTTP GET request using `requests.get()`
#
# Hint:
#   time.sleep(10)
#   response = requests.get('http://localhost:???/???')

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Make an HTTP GET request using `requests.get()`
#
# Hint:
#   response = requests.get('http://localhost:???/???')

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Open file `'grafana-datasource.json'` for writing and write the content
#
# Hint:
#   with open('grafana-datasource.json', 'w') as f:
#     f.write(content)

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Open file `'grafana-dashboard.json'` for writing and write the content
#
# Hint:
#   with open('grafana-dashboard.json', 'w') as f:
#     f.write(content)

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Open file `'alerting_rules.yml'` for writing and write the content
# 2. Open file `'prometheus.yml'` for writing and write the content
#
# Hint:
#   with open('alerting_rules.yml', 'w') as f:
#     f.write(content)
#   with open('prometheus.yml', 'w') as f:
#     f.write(content)

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Make an HTTP POST request using `requests.post()` with a JSON body
# 2. Make an HTTP GET request using `requests.get()`
# 3. Wait for services to become ready using `time.sleep(1)`
#
# Hint:
#   response = requests.post('http://localhost:???/???', json=???)
#   response = requests.get('http://localhost:???/???')
#   time.sleep(1)

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Implement the cell following the instructions in the markdown above
#
# Hint:
#   # ??? = SomeClass(param=???)
