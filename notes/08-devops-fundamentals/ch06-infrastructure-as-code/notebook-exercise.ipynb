# %% [markdown]
# # Ch.6 — Infrastructure as Code (Local Stack)
#
# > **Goal:** Provision Docker containers with Terraform — define infrastructure as declarative `.tf` files, version-control them in Git, and manage the full lifecycle (init → plan → apply → destroy).
# >
# > **Tech stack:** Terraform, Docker provider, HCL configuration language
# >
# > **What you'll build:** A reproducible infrastructure workflow running entirely on your local machine — no cloud dependencies.

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Run `terraform version` with the IPython shell magic
#
# Hint:
#   !terraform version ???
