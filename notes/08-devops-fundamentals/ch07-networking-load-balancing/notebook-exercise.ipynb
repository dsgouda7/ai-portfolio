# %%
# TODO: Implement this cell
#
# Steps:
# 1. Wait for services to become ready using `time.sleep(0.1)`
# 2. Open file `"app.py"` for writing and write the content
# 3. Open file `"Dockerfile"` for writing and write the content
# 4. Execute the `docker` command via `subprocess.run([...])`
# 5. Open file `"nginx.conf"` for writing and write the content
# 6. Open file `"docker-compose.yml"` for writing and write the content
# 7. Execute the `compose` command via `subprocess.run([...])`
# 8. Wait for services to become ready using `time.sleep(5)`
# 9. Make an HTTP GET request using `requests.get()`
# 10. Tally values using `collections.Counter`
# 11. Wait for services to become ready using `time.sleep(2)`
# 12. Run a shell command using `subprocess.run()`
# 13. Wait for services to become ready using `time.sleep(1)`
# 14. Run `aNULL` via IPython shell magic
# 15. Wait for services to become ready using `time.sleep(0.05)`
#
# Hint:
#   time.sleep(0.1)
#   with open("app.py", 'w') as f:
#     f.write(content)
#   with open("Dockerfile", 'w') as f:
#     f.write(content)
