# %% [markdown]
# # Ch.1 — Bagging & Random Forest

# %% [markdown]
# ## EnsembleAI Challenge
#
# **Goal**: Beat any single model by >5% via intelligent combination.
#
# | # | Constraint | Target |
# |---|-----------|--------|
# | 1 | IMPROVEMENT | >5% better than best single model |
# | 2 | DIVERSITY | Ensemble members must be sufficiently different |
# | 3 | EFFICIENCY | Latency < 5× single model |
# | 4 | INTERPRETABILITY | SHAP explains decisions |
# | 5 | ROBUSTNESS | More stable than any single model |
#
# This chapter: **Bagging & Random Forest** — reduce variance by averaging decorrelated trees.

# %% [markdown]
# ## Setup & Data

# %%
# TODO: Implement this cell
#  (Setup & Data)
#
# Steps:
# 1. Setup & Data
# 2. Compute `IMG` using `makedirs()`
# 3. Call `seed()` to produce the result
# 4. Compute `data` using `fetch_california_housing()`
# 5. Call `train_test_split()` to produce the result
# 6. Call `mean()` to produce the result
#
# Hint:
#    # implement using the APIs described above

# %% [markdown]
# ## Bootstrap Sampling Demo
#
# Each bootstrap sample draws $n$ items with replacement from $n$ training points.
# ~63% of original points are selected; the rest (~37%) are **out-of-bag (OOB)**.

# %%
# TODO: Implement this cell
#  (Bootstrap Sampling Demo)
#
# Steps:
# 1. Bootstrap Sampling Demo
# 2. Compute `oob_fractions` using `choice()`
# 3. Call `mean()` to produce the result
#
# Hint:
#    rng = np.random.default_rng(???)
#    bootstrap_idx = rng.choice(???)

# %% [markdown]
# ## Single Tree vs Random Forest (Regression)

# %%
# TODO: Implement this cell
#  (Single Tree vs Random Forest — Regression)
#
# Steps:
# 1. Single Tree vs Random Forest — Regression
# 2. Fit the model -- call `RandomForestRegressor()`
# 3. Fit the model -- call `sqrt()`
# 4. Process data
#
# Hint:
#    dt_reg = DecisionTreeRegressor(max_depth=???, random_state=???)
#    rf_reg = RandomForestRegressor(n_estimators=???, max_features=???)
#    rmse_dt = np.sqrt(???)
#    rmse_rf = np.sqrt(???)

# %% [markdown]
# ## Single Tree vs Random Forest (Classification)

# %%
# TODO: Implement this cell
#  (Single Tree vs Random Forest — Classification)
#
# Steps:
# 1. Single Tree vs Random Forest — Classification
# 2. Fit the model -- call `RandomForestClassifier()`
# 3. Fit the model -- call `f1_score()`
# 4. Process data
#
# Hint:
#    dt_cls = DecisionTreeClassifier(max_depth=???, random_state=???)
#    rf_cls = RandomForestClassifier(n_estimators=???, max_features=???)
#    dt_cls.fit(???)
#    dt_cls.predict(???)

# %%
# TODO: Implement this cell
#  (CONSTRAINT #2 VALIDATION: Diversity)
#
# Steps:
# 1. CONSTRAINT #2 VALIDATION: Diversity
# 2. Compute `upper_tri_idx` using `triangle()`
# 3. Compute `DIVERSITY_THRESHOLD`
# 4. Process data
#
# Hint:
#    rf_member_preds = np.array(???)
#    corr_matrix = np.corrcoef(???)
#    upper_tri_idx = np.triu_indices_from(???)
#    avg_corr = pairwise_corrs.mean(???)

# %% [markdown]
# ## Variance Reduction — How Many Trees Are Enough?

# %%
# TODO: Implement this cell
#  (Variance Reduction vs n_estimators)
#
# Steps:
# 1. Variance Reduction vs n_estimators
# 2. Fit the model -- call `RandomForestRegressor()`
# 3. Plot results -- call `subplots()`
#
# Hint:
#    m = RandomForestRegressor(n_estimators=???, max_features=???)
#    ax = plt.subplots(???)
#    m.fit(???)
#    m.predict(???)

# %% [markdown]
# ## Feature Importance (Random Forest)

# %%
# TODO: Implement this cell
#  (Feature Importances (averaged over 200 trees))
#
# Steps:
# 1. Feature Importances (averaged over 200 trees)
# 2. Plot results -- call `subplots()`
# 3. Call `importances()` to produce the result
#
# Hint:
#    sorted_idx = np.argsort(???)
#    ax = plt.subplots(???)

# %% [markdown]
# ## Decorrelation: `max_features` Effect

# %%
# TODO: Implement this cell
#  (Effect of max_features on ensemble quality)
#
# Steps:
# 1. Effect of max_features on ensemble quality
# 2. Fit the model -- call `append()`
# 3. Plot results -- call `subplots()`
# 4. Compute `ax2` using `twinx()`
# 5. Plot results -- call `get_legend_handles_labels()`
# 6. Call `8()` to produce the result
#
# Hint:
#    m = RandomForestRegressor(n_estimators=???, max_features=???)
#    ax1 = plt.subplots(???)
#    ax2 = ax1.twinx(???)
#    labels1 = ax1.get_legend_handles_labels(???)

# %% [markdown]
# ## Robustness: Stability Across Seeds

# %%
# TODO: Implement this cell
#  (Stability across random seeds)
#
# Steps:
# 1. Stability across random seeds
# 2. Fit the model -- call `DecisionTreeRegressor()`
# 3. Fit the model -- call `RandomForestRegressor()`
# 4. Plot results -- call `plot()`
# 5. Call `std()` to produce the result
#
# Hint:
#    dt_s = DecisionTreeRegressor(max_depth=???, random_state=???)
#    rf_s = RandomForestRegressor(n_estimators=???, max_features=???)
#    ax = plt.subplots(???)
#    dt_s.fit(???)

# %%
# TODO: Implement this cell
#  (CONSTRAINT #5 VALIDATION: Robustness)
#
# Steps:
# 1. CONSTRAINT #5 VALIDATION: Robustness
# 2. Compute `ROBUSTNESS_THRESHOLD`
# 3. Process data
#
# Hint:
#    dt_std = np.std(???)
#    rf_std = np.std(???)

# %% [markdown]
# ## OOB vs Test Score Convergence

# %%
# TODO: Implement this cell
#  (OOB vs Test R² across n_estimators)
#
# Steps:
# 1. OOB vs Test R² across n_estimators
# 2. Fit the model -- call `append()`
# 3. Plot results -- call `plot()`
# 4. Process data
#
# Hint:
#    m = RandomForestRegressor(n_estimators=???, max_features=???)
#    ax = plt.subplots(???)
#    m.fit(???)
#    m.predict(???)

# %% [markdown]
# ## What Can Go Wrong: RF Can't Extrapolate

# %%
# TODO: Implement this cell
#  (RF Extrapolation Failure)
#
# Steps:
# 1. RF Extrapolation Failure
# 2. Fit the model -- call `predict()`
#
# Hint:
#    rf_preds = rf_reg.predict(???)
#    rf_reg.predict(???)

# %% [markdown]
# ## Full Benchmark: DT vs RF (Regression + Classification)

# %%
# TODO: Implement this cell
#  (Full Benchmark)
#
# Steps:
# 1. Full Benchmark
# 2. Fit the model -- call `accuracy_score()`
# 3. Plot results -- call `subplots()`
# 4. Plot results -- call `bar()`
# 5. Plot results -- call `suptitle()`
#
# Hint:
#    axes = plt.subplots(???)
#    dt_reg.predict(???)

# %% [markdown]
# ## Progress Check
#
# | # | Constraint | Status | Evidence |
# |---|-----------|--------|----------|
# | 1 | IMPROVEMENT >5% | | RF RMSE < DT RMSE by >10% |
# | 2 | DIVERSITY | | Bootstrap + feature randomization |
# | 3 | EFFICIENCY | ⏳ | Not yet benchmarked |
# | 4 | INTERPRETABILITY | | Global importance only; SHAP in Ch.4 |
# | 5 | ROBUSTNESS | | RF std(RMSE) << DT std(RMSE) across seeds |
#
# **Next**: Ch.2 — Boosting reduces **bias** via sequential error correction.

# %% [markdown]
# ## Exercises
#
# 1. **OOB convergence**: For `n_estimators` in `[10, 20, 50, 100, 200, 500]`, plot both `oob_score_` and test R² on the same axis. At what point does OOB converge to test R²?
# 2. **max_features sweep**: Train RF with `max_features` in `[1, 2, 3, 4, 6, 8]`. Plot test RMSE. Is `'sqrt'` (~3) optimal?
# 3. **Extrapolation test**: Create synthetic data where test targets exceed training range. Show that RF predictions are bounded by training range while linear regression extrapolates.

# %%
# TODO: Implement this cell
#  (Exercise 1: OOB convergence)
#
# Steps:
# 1. Exercise 1: OOB convergence
#
# Hint:
#    rf_n = RandomForestRegressor(n_estimators=???, oob_score=???)
#    rf_n.fit(???)
#    rf_n.predict(???)

# %%
# TODO: Implement this cell
#  (Exercise 2: max_features sweep)
#
# Steps:
# 1. Exercise 2: max_features sweep
#
# Hint:
#    rf_mf = RandomForestRegressor(n_estimators=???, max_features=???)
#    rf_mf.fit(???)

# %%
# TODO: Implement this cell
#  (Exercise 3: Extrapolation test)
#
# Steps:
# 1. Exercise 3: Extrapolation test
#
# Hint:
#    RF.predict(???)

# %% [markdown]
# ## Ensemble Extensions — Boosting and Benchmarking
# **Track:** ML from Scratch · California Housing — regression benchmark + ensemble comparison

# %% [markdown]
# ## Core Idea
#
# **Bagging (Random Forest):** train 100–500 independent trees on bootstrapped data. Average predictions → variance drops by $\sim 1/N$ (minus a floor set by inter-tree correlation $\rho$).
#
# $$\text{Var}(\text{ensemble}) = \rho\sigma^2 + \frac{1-\rho}{N}\sigma^2$$
#
# **Boosting (XGBoost):** train trees sequentially, each fitting the residuals of the previous ensemble → bias drops with each round.
#
# ```
# Random Forest: parallel trees → variance reduction
# XGBoost: sequential trees → bias reduction (+ regularisation)
# ```
#
# This section extends the random-forest foundation with a stronger benchmark and a first look at boosting.

# %% [markdown]
# ## Running Example
#
# **Regression:** predict California district median house value from all 8 features.
# We benchmark Linear Regression (Ch.1 baseline) → Decision Tree → Random Forest → XGBoost.
#
# **Classification:** the same data can be binarized into a high-value / low-value task, but the focus here remains on **ensemble behavior** rather than standalone margin-based classifiers.
#
# Same dataset throughout — differences in RMSE and R² are purely the model, not the data.

# %%
# TODO: Implement this cell
#  (Data for benchmark extension)
#
# Steps:
# 1. Process data
# 2. Data for benchmark extension
# 3. Call `train_test_split()` to produce the result
# 4. Fit the model -- call `StandardScaler()`
# 5. Call `mean()` to produce the result
#
# Hint:
#    scaler = StandardScaler(???)
#    X_tr_sc = scaler.fit_transform(???)
#    X_te_sc = scaler.transform(???)
#    scaler.transform(???)

# %% [markdown]
# ## Random Forest — Bagging in Action
#
# Each tree sees a bootstrapped subset of training rows and a random subset of features at each split.
# The OOB (out-of-bag) examples — the ~37% not sampled into each tree — give a free validation estimate.

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Fit the model -- call `RandomForestRegressor()`
# 2. Fit the model -- call `predict()`
# 3. Call `Forest()` to produce the result
#
# Hint:
#    rf = RandomForestRegressor(n_estimators=???, max_features=???)
#    y_pred_rf = rf.predict(???)
#    rmse_rf = np.sqrt(???)
#    rf.fit(???)

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Compute `rf_importances` using `trees()`
# 2. Plot results -- call `subplots()`
# 3. Call `importances()` to produce the result
#
# Hint:
#    sorted_idx = np.argsort(???)
#    ax = plt.subplots(???)

# %% [markdown]
# ## Variance Reduction — How Many Trees Are Enough?

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Compute `n_trees_range`
# 2. Fit the model -- call `RandomForestRegressor()`
# 3. Plot results -- call `subplots()`
# 4. Process data
#
# Hint:
#    m = RandomForestRegressor(n_estimators=???, max_features=???)
#    preds = m.predict(???)
#    ax = plt.subplots(???)
#    m.fit(???)

# %% [markdown]
# ## XGBoost — Gradient Boosting
#
# Each tree fits the **negative gradient of the loss** w.r.t. current predictions — for MSE, this is the residual:
#
# $$F_m(\mathbf{x}) = F_{m-1}(\mathbf{x}) + \eta \cdot h_m(\mathbf{x}), \quad h_m \text{ fits } \{y_i - F_{m-1}(\mathbf{x}_i)\}$$
#
# `early_stopping_rounds` halts training when validation RMSE stops improving — essential to prevent overfitting.

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Process data
#
# Hint:
#    # implement using the APIs described above

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Call `train_test_split()` to produce the result
# 2. Fit the model -- call `XGBRegressor()`
# 3. Fit the model -- call `predict()`
# 4. Process data
#
# Hint:
#    xgb = XGBRegressor(n_estimators=???, learning_rate=???)
#    y_pred_xgb = xgb.predict(???)
#    rmse_xgb = np.sqrt(???)
#    xgb.fit(???)

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Call `evals_result()` to produce the result
# 2. Plot results -- call `subplots()`
#
# Hint:
#    val_rmse = xgb.evals_result(???)
#    ax = plt.subplots(???)

# %% [markdown]
# ## Full Regression Benchmark
#
# Linear Regression (Ch.1 baseline) → Decision Tree → Random Forest → XGBoost
#
# Each successive model adds complexity. Does it pay off in RMSE?

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Fit the model -- call `fit()`
# 2. Fit the model -- call `predict()`
# 3. Call `append()` to produce the result
# 4. Plot results -- call `subplots()`
# 5. Plot results -- call `bar()`
# 6. Plot results -- call `suptitle()`
#
# Hint:
#    lr = LinearRegression(???)
#    dt = DecisionTreeRegressor(max_depth=???, random_state=???)
#    rmse = np.sqrt(???)
#    axes = plt.subplots(???)

# %% [markdown]
# ## What Can Go Wrong — Boosting on Noisy Labels

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Call `default_rng()` to produce the result
# 2. Call `train_test_split()` to produce the result
# 3. Fit the model -- call `XGBRegressor()`
# 4. Call `stopping()` to produce the result
#
# Hint:
#    xgb_no_es = XGBRegressor(n_estimators=???, learning_rate=???)
#    xgb_es = XGBRegressor(n_estimators=???, learning_rate=???)
#    rng = np.random.default_rng(???)
#    y_tr_noisy = y_tr.copy(???)

# %% [markdown]
# ## XGBoost Feature Importances vs Random Forest

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Process data
# 2. Plot results -- call `subplots()`
# 3. Plot results -- call `suptitle()`
# 4. Process data
#
# Hint:
#    axes = plt.subplots(???)
#    order = np.argsort(???)

# %% [markdown]
# ## Exercises
#
# 1. **Random Forest depth sweep:** sweep `max_depth` over `[4, 8, 12, None]`. Plot test RMSE and OOB R². Where does the variance/bias trade-off look best?
# 2. **OOB vs test score:** for `n_estimators` in `[10, 20, 50, 100, 200, 500]`, plot both `oob_score_` and test R² on the same axis. When does OOB converge to test R²?
# 3. **XGBoost learning rate:** train XGBoost with `learning_rate` in `[0.3, 0.1, 0.05, 0.01]`, each with early stopping. Plot test RMSE vs best iteration for each learning rate. What is the trade-off?

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Implement the cell logic
#
# Hint:
#    rf_depth = RandomForestRegressor(n_estimators=???, max_depth=???)
#    rf_n = RandomForestRegressor(n_estimators=???, oob_score=???)
#    rmse = np.sqrt(???)
#    rf_depth.fit(???)
