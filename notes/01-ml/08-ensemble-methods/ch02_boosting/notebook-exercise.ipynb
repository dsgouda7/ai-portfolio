# %% [markdown]
# # Ch.2 — Boosting: AdaBoost & Gradient Boosting

# %% [markdown]
# ## EnsembleAI Challenge — Ch.2
#
# Ch.1 showed **bagging** reduces variance. This chapter: **boosting** reduces **bias**.
#
# - **AdaBoost**: Reweight misclassified samples → next learner focuses on hard cases
# - **Gradient Boosting**: Each tree fits the *residuals* of the current ensemble

# %% [markdown]
# ## Setup & Data

# %%
# TODO: Implement this cell
#  (Setup & Data)
#
# Steps:
# 1. Setup & Data
# 2. Compute `IMG` using `makedirs()`
# 3. Call `seed()` to produce the result
# 4. Compute `data` using `fetch_california_housing()`
# 5. Call `train_test_split()` to produce the result
# 6. Process data
#
# Hint:
#    # implement using the APIs described above

# %% [markdown]
# ## AdaBoost — Sequential Sample Reweighting

# %%
# TODO: Implement this cell
#  (AdaBoost Classification)
#
# Steps:
# 1. AdaBoost Classification
# 2. Fit the model -- call `AdaBoostClassifier()`
# 3. Fit the model -- call `DecisionTreeClassifier()`
# 4. Fit the model -- call `f1_score()`
#
# Hint:
#    ada_stumps = AdaBoostClassifier(estimator=???, max_depth=???)
#    ada_trees = AdaBoostClassifier(estimator=???, max_depth=???)
#    ada_stumps.fit(???)
#    dt_base.predict(???)

# %% [markdown]
# ## AdaBoost Staged Performance

# %%
# TODO: Implement this cell
#  (AdaBoost: accuracy vs boosting rounds)
#
# Steps:
# 1. AdaBoost: accuracy vs boosting rounds
# 2. Plot results -- call `subplots()`
#
# Hint:
#    ax = plt.subplots(???)
#    dt_base.predict(???)

# %% [markdown]
# ## Gradient Boosting — Fitting Residuals
#
# Each tree fits: $h_m(\mathbf{x}) \approx y - F_{m-1}(\mathbf{x})$ (the residual).
#
# Update: $F_m = F_{m-1} + \eta \cdot h_m$

# %%
# TODO: Implement this cell
#  (Gradient Boosting Regression)
#
# Steps:
# 1. Gradient Boosting Regression
# 2. Fit the model -- call `sqrt()`
#
# Hint:
#    gb = GradientBoostingRegressor(n_estimators=???, learning_rate=???)
#    rmse_gb = np.sqrt(???)
#    gb.fit(???)
#    gb.predict(???)

# %% [markdown]
# ## Visualize Residuals Shrinking

# %%
# TODO: Implement this cell
#  (Residual Shrinkage Across Boosting Rounds)
#
# Steps:
# 1. Residual Shrinkage Across Boosting Rounds
# 2. Plot results -- call `subplots()`
#
# Hint:
#    ax = plt.subplots(???)

# %% [markdown]
# ## Learning Rate Trade-off

# %%
# TODO: Implement this cell
#  (Learning Rate Effect)
#
# Steps:
# 1. Learning Rate Effect
# 2. Plot results -- call `GradientBoostingRegressor()`
# 3. Plot results -- call `set_xlabel()`
#
# Hint:
#    gb_lr = GradientBoostingRegressor(n_estimators=???, learning_rate=???)
#    ax = plt.subplots(???)
#    gb_lr.fit(???)

# %% [markdown]
# ## Bagging vs Boosting Benchmark

# %%
# TODO: Implement this cell
#  (RF vs GB Comparison)
#
# Steps:
# 1. RF vs GB Comparison
# 2. Fit the model -- call `DecisionTreeRegressor()`
# 3. Fit the model -- call `Forest()`
# 4. Plot results -- call `subplots()`
#
# Hint:
#    rf = RandomForestRegressor(n_estimators=???, max_features=???)
#    dt = DecisionTreeRegressor(max_depth=???, random_state=???)
#    rmse_rf = np.sqrt(???)
#    rmse_dt = np.sqrt(???)

# %% [markdown]
# ## What Can Go Wrong: Boosting on Noisy Labels

# %%
# TODO: Implement this cell
#  (Noise Overfitting Demo)
#
# Steps:
# 1. Noise Overfitting Demo
# 2. Fit the model -- call `GradientBoostingRegressor()`
# 3. Fit the model -- call `sqrt()`
# 4. Call `stopping()` to produce the result
#
# Hint:
#    gb_noisy = GradientBoostingRegressor(n_estimators=???, learning_rate=???)
#    gb_noisy_es = GradientBoostingRegressor(n_estimators=???, learning_rate=???)
#    rng = np.random.default_rng(???)
#    y_tr_noisy = y_tr.copy(???)

# %% [markdown]
# ## Progress Check
#
# | # | Constraint | Status | Evidence |
# |---|-----------|--------|----------|
# | 1 | IMPROVEMENT >5% | | GB beats RF on RMSE |
# | 2 | DIVERSITY | | Sequential trees correct different errors |
# | 3 | EFFICIENCY | ⏳ | Sequential training is slower |
# | 4 | INTERPRETABILITY | | Feature importance available |
# | 5 | ROBUSTNESS | | Needs early stopping on noisy data |
#
# **Next**: Ch.3 — XGBoost, LightGBM, CatBoost (industrial-strength boosting).

# %% [markdown]
# ## Exercises
#
# 1. **AdaBoost depth sweep**: Train AdaBoost with base tree `max_depth` in `[1, 2, 3, 5, 10]`. Plot test F1. What depth works best for boosting?
# 2. **Subsample effect**: Train GradientBoostingRegressor with `subsample` in `[0.5, 0.7, 0.8, 0.9, 1.0]`. Plot test RMSE. Does stochastic gradient boosting help?
# 3. **Bias-variance decomposition**: For the same dataset, compute RMSE for RF (bagging) vs GB (boosting) across 10 random seeds. Which has lower variance? Lower bias?

# %%
# TODO: Implement this cell
#  (Exercise 1: AdaBoost depth sweep)
#
# Steps:
# 1. Exercise 1: AdaBoost depth sweep
#
# Hint:
#    ada = AdaBoostClassifier(estimator=???, max_depth=???)
#    ada.fit(???)

# %%
# TODO: Implement this cell
#  (Exercise 2: Subsample effect)
#
# Steps:
# 1. Exercise 2: Subsample effect
#
# Hint:
#    gb_ss = GradientBoostingRegressor(subsample=???)
#    gb_ss.fit(???)

# %%
# TODO: Implement this cell
#  (Exercise 3: Bias-variance across seeds)
#
# Steps:
# 1. Exercise 3: Bias-variance across seeds
#
# Hint:
#    # implement using the APIs described above
