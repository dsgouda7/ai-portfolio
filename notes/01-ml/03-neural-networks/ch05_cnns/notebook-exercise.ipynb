# %% [markdown]
# # Ch.5 — CNNs
# **Track:** ML from Scratch · Synthetic neighbourhood grid images

# %% [markdown]
# ## Core Idea
#
# A **Convolutional Neural Network** applies learned filters that slide across the input — sharing the same weights at every spatial position.
#
# ```
# Dense (Ch.2): 64 × 128 + 128 = 8,320 params for first layer
# CNN: (3×3×1 + 1) × 8 = 80 params for equivalent first conv layer
# ```
#
# Key ingredients: **Convolution → ReLU → Pooling**, repeated, then **Dense head**.

# %% [markdown]
# ## Running Example
#
# Synthetic **8×8 neighbourhood grid images** (greyscale):
# - `label=0` (tidy): high mean brightness, low variance
# - `label=1` (distressed): low mean brightness, high variance (patchy lots)
#
# This mirrors real property-condition classification from aerial imagery — same task, fully self-contained without downloading external data.

# %%
def make_neighbourhood_grids(n_samples=2000, grid_size=8, seed=42):
    """
    TODO #1: Implement `make_neighbourhood_grids()`.

    Steps:
    1. Evaluate performance metrics
    2. Synthetic image dataset
    3. Call `train_test_split()` to produce the result
    4. Call `bincount()` to produce the result

    Hint:
    rng = np.random.default_rng(???)
    grid = rng.normal(???)

    Returns: np.array(X, dtype=np.float32), np.arr...
    """
    raise NotImplementedError("TODO: implement make_neighbourhood_grids()")

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Plot results -- call `subplots()`
# 2. Plot results -- call `suptitle()`
#
# Hint:
#    axes = plt.subplots(???)

# %% [markdown]
# ## Manual 2D Convolution (NumPy)
#
# $$
# (\mathbf{X} * \mathbf{K})_{i,j} = \sum_{u=0}^{k-1}\sum_{v=0}^{k-1} \mathbf{X}_{i+u,\,j+v} \cdot \mathbf{K}_{u,v}
# $$
#
# Output size (no padding, stride 1): $H_\text{out} = H - k + 1$

# %%
def conv2d_numpy(x, kernel, stride=1, padding=0):
    """
    TODO #3: Implement `conv2d_numpy()`.

    Steps:
    1. Define helper function `conv2d_numpy()`
    2. Define helper function `maxpool2d_numpy()`
    3. Demo on one tidy and one distressed grid
    4. Compute `edge_kernel` using `kernel()`
    5. Compute `tidy_edge`
    6. Compute `tidy_pool` using `maximum()`
    7. Plot results -- call `imshow()`
    8. Plot results -- call `suptitle()`

    Hint:
    x = np.pad(???)
    out = np.zeros(???)
    edge_kernel = np.array(???)
    axes = plt.subplots(???)

    Returns: out
    """
    raise NotImplementedError("TODO: implement conv2d_numpy()")

def maxpool2d_numpy(x, pool_size=2):
    """
    TODO #3: Implement `maxpool2d_numpy()`.

    Steps:
    1. Define helper function `conv2d_numpy()`
    2. Define helper function `maxpool2d_numpy()`
    3. Demo on one tidy and one distressed grid
    4. Compute `edge_kernel` using `kernel()`
    5. Compute `tidy_edge`
    6. Compute `tidy_pool` using `maximum()`
    7. Plot results -- call `imshow()`
    8. Plot results -- call `suptitle()`

    Hint:
    x = np.pad(???)
    out = np.zeros(???)
    edge_kernel = np.array(???)
    axes = plt.subplots(???)

    Returns: out
    """
    raise NotImplementedError("TODO: implement maxpool2d_numpy()")

# %% [markdown]
# ## Filter Visualisation — What Different Kernels Detect
#
# Different hand-crafted kernels detect different patterns. CNNs learn these kernels automatically from data.

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Compute `kernels` using `array()`
# 2. Plot results -- call `subplots()`
# 3. Plot results -- call `items()`
# 4. Plot results -- call `suptitle()`
#
# Hint:
#    axes = plt.subplots(???)

# %% [markdown]
# ## Parameter Count: Dense vs CNN
#
# Why do CNNs need far fewer parameters for the same input?

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Compute `input_pixels`
# 2. Compute `dense_params`
# 3. Compute `conv_params`
# 4. Call `Dense()` to produce the result
# 5. Compute `large_input` using `Dense()`
#
# Hint:
#    # implement using the APIs described above

# %% [markdown]
# ## CNN Classifier with Keras
#
# Build and train a CNN on the synthetic neighbourhood grids.
# Architecture: `Input(1,8,8) → Conv(8,3×3) → MaxPool → Conv(16,3×3) → Flatten → Dense(32) → Dense(1, sigmoid)`

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Process data
#
# Hint:
#    # implement using the APIs described above

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Call `set_seed()` to produce the result
# 2. Call `transpose()` to produce the result
# 3. Call `Conv2D()` to produce the result
# 4. Call `compile()` to produce the result
#
# Hint:
#    X_tr_cl = X_tr.transpose(???)
#    X_te_cl = X_te.transpose(???)
#    cnn = keras.Sequential(???)
#    cnn.compile(???)

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Fit the model -- call `fit()`
# 2. Fit the model -- call `predict()`
# 3. Plot results -- call `plot()`
# 4. Plot results -- call `suptitle()`
#
# Hint:
#    history = cnn.fit(???)
#    y_pred_prob = cnn.predict(???)
#    axes = plt.subplots(???)
#    cnn.fit(???)

# %% [markdown]
# ## Learned Filter Visualisation
#
# After training, the first conv layer's 8 filters have been learned from data. Visualise them and their responses.

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Call `shape()` to produce the result
# 2. Plot results -- call `subplots()`
# 3. Plot results -- call `conv2d_numpy()`
# 4. Plot results -- call `set_ylabel()`
#
# Hint:
#    axes = plt.subplots(???)

# %% [markdown]
# ## Filter Depth Sweep — How Many Filters?
#
# Vary the number of filters in the first conv layer and track test accuracy.

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Process data
# 2. Fit the model -- call `Dense()`
# 3. Plot results -- call `subplots()`
#
# Hint:
#    m = keras.Sequential(???)
#    acc = m.evaluate(???)
#    ax = plt.subplots(???)
#    m.fit(???)

# %% [markdown]
# ## Trap 1 — Kernel Size Too Large for Small Inputs
#
# A 5×5 kernel on an 8×8 input (no padding, stride 1) produces a 4×4 output. After MaxPool(2×2) → 2×2. One more conv(3×3): output is 0×0 — the network crashes.

# %%
def output_size(h, k, s=1, p=0):
    """
    TODO #11: Implement `output_size()`.

    Steps:
    1. Process data
    2. Define helper function `output_size()`
    3. Process data
    4. Call `floor()` to produce the result

    Hint:
    # implement using the APIs described above

    Returns: math.floor((h + 2*p - k) / s) + 1
    """
    raise NotImplementedError("TODO: implement output_size()")

# %% [markdown]
# ## Trap 2 — Unscaled Pixel Values
#
# If pixel values are in [0, 255] instead of [0, 1], the first conv layer receives activations ~100× larger than expected. Gradients from the first layer are correspondingly larger → unstable training.

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Compute `X_unscaled`
# 2. Compute `rng` using `default_rng()`
# 3. Compute `sample_scaled`
# 4. Compute `act_scaled` using `conv2d_numpy()`
# 5. Call `mean()` to produce the result
#
# Hint:
#    rng = np.random.default_rng(???)
#    rand_filter = rng.normal(???)

# %% [markdown]
# ## Exercises
#
# **Exercise 1 — Global Average Pooling vs Flatten**
# Replace the `Flatten()` layer with `GlobalAveragePooling2D()` in the Keras model. Compare parameter counts and test accuracy. When would GAP be preferable?
#
# **Exercise 2 — Receptive field calculator**
# Implement a function `receptive_field(n_layers, k)` that computes $1 + n \times (k-1)$. Plot the receptive field for `k=3` and `n_layers` from 1 to 10. At what depth does the receptive field exceed the 8×8 input?
#
# **Exercise 3 — Custom edge detector**
# Generate a batch of synthetic grids where the tidy class has strong horizontal banding and the distressed class has random noise. Design a hand-crafted horizontal-edge kernel that achieves > 80% accuracy using only threshold classification on the mean filter response (no neural network needed). What does this tell you about the role of prior knowledge vs learned features?

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Call `Conv2D()` to produce the result
#
# Hint:
#    cnn_gap = keras.Sequential(???)
#    cnn_gap.compile(???)

# %%
def receptive_field(n_layers, k, stride=1):
    """
    TODO #14: Implement `receptive_field()`.

    Steps:
    1. Define helper function `receptive_field()`
    2. Compute `layers_range`
    3. Plot results -- call `plot()`

    Hint:
    # implement using the APIs described above

    Returns: 1 + n_layers * (k - 1)  # stride=1, p...
    """
    raise NotImplementedError("TODO: implement receptive_field()")

# %%
def make_banded_grids(n_samples=500, grid_size=8, seed=42):
    """
    TODO #15: Implement `make_banded_grids()`.

    Steps:
    1. Define helper function `make_banded_grids()`
    2. Call `append()` to produce the result
    3. Call `array()` to produce the result
    4. Compute `h_kernel` using `array()`

    Hint:
    rng = np.random.default_rng(???)
    g = np.zeros(???)
    h_kernel = np.array(???)

    Returns: np.array(X, dtype=np.float32), np.arr...
    """
    raise NotImplementedError("TODO: implement make_banded_grids()")
