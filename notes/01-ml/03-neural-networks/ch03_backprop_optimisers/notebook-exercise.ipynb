# %% [markdown]
# # Ch.3 — Backprop & Optimisers
# **Track:** ML from Scratch · California Housing dataset

# %% [markdown]
# ## Core Idea
#
# **Backpropagation** applies the chain rule backwards through the network to compute $\nabla_W \mathcal{L}$ for every weight.
#
# **Optimisers** use those gradients to update weights:
# ```
# SGD → Momentum → RMSProp → Adam
# (bare) (velocity) (adaptive scale) (both combined)
# ```

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Process data
# 2. Compute `housing` using `fetch_california_housing()`
# 3. Fit the model -- call `StandardScaler()`
# 4. Process data
#
# Hint:
#    scaler = StandardScaler(???)
#    X_train_s = scaler.fit_transform(???)
#    X_test_s = scaler.transform(???)
#    scaler.transform(???)

# %% [markdown]
# ## Manual Backprop (NumPy)
#
# Network: 8 → 64 → 32 → 1
# Loss: MSE. One forward pass + backward pass from scratch.
#
# Forward pass stores:
# - $z^{(l)}$ — pre-activation (needed for ReLU derivative)
# - $h^{(l)}$ — post-activation (needed for weight gradient)
#
# Backward pass:
# $$\delta^{(L)} = \frac{2}{n}(\hat{y} - y) \qquad \delta^{(l)} = (W_{l+1}\,\delta^{(l+1)}) \odot \mathbf{1}[z^{(l)}>0]$$
# $$\nabla_{W_l} = h^{(l-1)\top} \delta^{(l)} \qquad \nabla_{b_l} = \sum_\text{batch} \delta^{(l)}$$

# %%
def he_init(n_in, n_out):
    """
    TODO #2: Implement `he_init()`.

    Steps:
    1. He initialisation + manual forward/backward pass
    2. Define helper function `he_init()`
    3. Compute `params` using `append()`
    4. Define helper function `relu()` and `relu_grad()`
    5. Define helper function `forward()`
    6. Define helper function `backward()`
    7. Call `error()` to produce the result
    8. Process data
    9. Compute `grads`
    10. Process data

    Hint:
    rng = np.random.default_rng(???)
    db = delta.sum(???)

    Returns: rng.normal(0, np.sqrt(2 / n_in), (n_i...
    """
    raise NotImplementedError("TODO: implement he_init()")

def relu(z):
    """
    TODO #2: Implement `relu()`.

    Steps:
    1. He initialisation + manual forward/backward pass
    2. Define helper function `he_init()`
    3. Compute `params` using `append()`
    4. Define helper function `relu()` and `relu_grad()`
    5. Define helper function `forward()`
    6. Define helper function `backward()`
    7. Call `error()` to produce the result
    8. Process data
    9. Compute `grads`
    10. Process data

    Hint:
    rng = np.random.default_rng(???)
    db = delta.sum(???)

    Returns: rng.normal(0, np.sqrt(2 / n_in), (n_i...
    """
    raise NotImplementedError("TODO: implement relu()")

def relu_grad(z):
    """
    TODO #2: Implement `relu_grad()`.

    Steps:
    1. He initialisation + manual forward/backward pass
    2. Define helper function `he_init()`
    3. Compute `params` using `append()`
    4. Define helper function `relu()` and `relu_grad()`
    5. Define helper function `forward()`
    6. Define helper function `backward()`
    7. Call `error()` to produce the result
    8. Process data
    9. Compute `grads`
    10. Process data

    Hint:
    rng = np.random.default_rng(???)
    db = delta.sum(???)

    Returns: rng.normal(0, np.sqrt(2 / n_in), (n_i...
    """
    raise NotImplementedError("TODO: implement relu_grad()")

def forward(X, params):
    """
    TODO #2: Implement `forward()`.

    Steps:
    1. He initialisation + manual forward/backward pass
    2. Define helper function `he_init()`
    3. Compute `params` using `append()`
    4. Define helper function `relu()` and `relu_grad()`
    5. Define helper function `forward()`
    6. Define helper function `backward()`
    7. Call `error()` to produce the result
    8. Process data
    9. Compute `grads`
    10. Process data

    Hint:
    rng = np.random.default_rng(???)
    db = delta.sum(???)

    Returns: rng.normal(0, np.sqrt(2 / n_in), (n_i...
    """
    raise NotImplementedError("TODO: implement forward()")

def backward(y_hat, y, cache, params):
    """
    TODO #2: Implement `backward()`.

    Steps:
    1. He initialisation + manual forward/backward pass
    2. Define helper function `he_init()`
    3. Compute `params` using `append()`
    4. Define helper function `relu()` and `relu_grad()`
    5. Define helper function `forward()`
    6. Define helper function `backward()`
    7. Call `error()` to produce the result
    8. Process data
    9. Compute `grads`
    10. Process data

    Hint:
    rng = np.random.default_rng(???)
    db = delta.sum(???)

    Returns: rng.normal(0, np.sqrt(2 / n_in), (n_i...
    """
    raise NotImplementedError("TODO: implement backward()")

# %% [markdown]
# ## Manual SGD Training Loop
#
# Train the network for 200 epochs with vanilla SGD. Store the loss at each epoch so we can compare with other optimisers.

# %%
def mse_loss(y_hat, y):
    """
    TODO #3: Implement `mse_loss()`.

    Steps:
    1. Define helper function `mse_loss()`
    2. Define helper function `train_sgd()`
    3. Call `SGD()` to produce the result

    Hint:
    rng = np.random.default_rng(???)
    idx = rng.permutation(???)

    Returns: np.mean((y_hat - y) ** 2)
    """
    raise NotImplementedError("TODO: implement mse_loss()")

def train_sgd(X, y, lr=0.01, epochs=200, batch_size=256, seed=42):
    """
    TODO #3: Implement `train_sgd()`.

    Steps:
    1. Define helper function `mse_loss()`
    2. Define helper function `train_sgd()`
    3. Call `SGD()` to produce the result

    Hint:
    rng = np.random.default_rng(???)
    idx = rng.permutation(???)

    Returns: np.mean((y_hat - y) ** 2)
    """
    raise NotImplementedError("TODO: implement train_sgd()")

# %% [markdown]
# ## Optimiser Comparison — sklearn MLPRegressor
#
# sklearn exposes SGD, SGD+Momentum, and Adam via `solver` and `momentum` params. We compare loss curves and final R².

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Compute `EPOCHS`
# 2. Compute `configs`
# 3. Fit the model -- call `MLPRegressor()`
#
# Hint:
#    m = MLPRegressor(hidden_layer_sizes=???, activation=???)
#    m.fit(???)
#    m.predict(???)

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Compute `colors`
# 2. Plot results -- call `subplots()`
# 3. Plot results -- call `items()`
# 4. Plot results -- call `keys()`
# 5. Plot results -- call `suptitle()`
#
# Hint:
#    axes = plt.subplots(???)

# %% [markdown]
# ## Manual Adam Implementation (NumPy)
#
# Implement Adam from scratch to see the bias-correction mechanism in action.

# %%
def train_adam(X, y, lr=1e-3, epochs=200, batch_size=256, seed=42):
    """
    TODO #6: Implement `train_adam()`.

    Steps:
    1. Define helper function
    2. Define helper function `train_adam()`
    3. Call `Adam()` to produce the result
    4. Plot results -- call `Adam()`
    5. Call `forward()` to produce the result

    Hint:
    opt = AdamOptimiser(lr=???)
    rng = np.random.default_rng(???)
    idx = rng.permutation(???)
    ax = plt.subplots(???)

    Returns: local_params, losses
    """
    raise NotImplementedError("TODO: implement train_adam()")

# %% [markdown]
# ## Learning Rate Sweep
#
# What happens when learning rate is too high, too low, or just right?

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Compute `lr_values`
# 2. Fit the model -- call `MLPRegressor()`
# 3. Plot results -- call `subplots()`
#
# Hint:
#    m = MLPRegressor(hidden_layer_sizes=???)
#    ax = plt.subplots(???)
#    m.fit(???)
#    m.predict(???)

# %% [markdown]
# ## Trap 1 — High Learning Rate Divergence
#
# A learning rate that is too large causes the optimizer to step over the minimum. Loss oscillates or diverges entirely.

# %%
def train_sgd_safe(X, y, lr=1.0, epochs=40, batch_size=256, seed=42):
    """
    TODO #8: Implement `train_sgd_safe()`.

    Steps:
    1. Define helper function `train_sgd_safe()`
    2. Compute `losses_good`
    3. Plot results -- call `subplots()`
    4. Plot results -- call `if()`
    5. Plot results -- call `set_xlabel()`

    Hint:
    rng = np.random.default_rng(???)
    idx = rng.permutation(???)
    ax = plt.subplots(???)
    lr = 0.01(???)

    Returns: losses   # stop early — diverged
    """
    raise NotImplementedError("TODO: implement train_sgd_safe()")

# %% [markdown]
# ## Trap 2 — Adam Masks Bad Architecture
#
# Adam's adaptive scaling can make even a poor architecture look like it converges. Switch to SGD to expose the real quality of the model.

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Compute `tiny`
# 2. Fit the model -- call `r2_score()`
# 3. Call `R²()` to produce the result
# 4. Process data
#
# Hint:
#    m = MLPRegressor(hidden_layer_sizes=???, activation=???)
#    m.predict(???)

# %% [markdown]
# ## Exercises
#
# **Exercise 1 — Gradient clipping**
# Modify `train_sgd_safe` to clip gradients to $[-1, 1]$ before the weight update (`np.clip`). Does it allow a higher learning rate (e.g., 0.5) to converge without diverging?
#
# **Exercise 2 — Cosine LR schedule**
# Implement a cosine annealing schedule:
# $\eta_t = \eta_{\min} + \tfrac{1}{2}(\eta_{\max}-\eta_{\min})(1 + \cos(\pi t / T))$
# Update the manual Adam loop to use it. Plot the LR schedule alongside the loss curve.
#
# **Exercise 3 — Momentum visualisation**
# Using `MLPRegressor(solver='sgd', momentum=m)` for `m` in `[0.0, 0.5, 0.9, 0.99]`, plot the 4 loss curves on a single plot. At what momentum value does the optimiser start overshooting?

# %%
def train_sgd_clipped(X, y, lr=0.5, clip=1.0, epochs=60, batch_size=256, seed=42):
    """
    TODO #10: Implement `train_sgd_clipped()`.

    Steps:
    1. Define helper function `train_sgd_clipped()`

    Hint:
    rng = np.random.default_rng(???)
    idx = rng.permutation(???)

    Returns: losses
    """
    raise NotImplementedError("TODO: implement train_sgd_clipped()")

# %%
def cosine_lr(epoch, T, lr_min=1e-5, lr_max=1e-3):
    """
    TODO #11: Implement `cosine_lr()`.

    Steps:
    1. Define helper function `cosine_lr()`

    Hint:
    # implement using the APIs described above

    Returns: lr_max  # placeholder — replace with ...
    """
    raise NotImplementedError("TODO: implement cosine_lr()")

# %%
# TODO: Implement this cell
#
# Steps:
# 1. Compute `momentum_values`
# 2. Plot results -- call `subplots()`
# 3. Plot results -- call `set_xlabel()`
#
# Hint:
#    m_model = MLPRegressor(hidden_layer_sizes=???)
#    ax = plt.subplots(???)
